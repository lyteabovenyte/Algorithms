# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap08/8_1_MNIST_1D_Performance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.1: MNIST_1D_Performance**
#
# This notebook runs a simple neural network on the MNIST1D dataset as in figure 8.2a. It uses code from https://github.com/greydanus/mnist1d to generate the data.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# %pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-rd_swgxk
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-rd_swgxk
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (2.32.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (1.14.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.1.31)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14625 sha256=4151ae9937597650b94d1efce40e057e9998f8e82cf2665f9af83453077c21a6
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ycn7re50/wheels/d6/38/42/3d2112bc7d915f6195254ac85eb761d922d1b18f52817aa8e2
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d

# %% [markdown]
# Let's generate a training and test dataset using the MNIST1D code.  The dataset gets saved as a .pkl file so it doesn't have to be regenerated each time.

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
D_i = 40    # Input dimensions
D_k = 100   # Hidden dimensions
D_o = 10    # Output dimensions
# TODO:
# Define a model with two hidden layers of size 100
# And ReLU activations between them
# Replace this line (see Figure 7.8 of book for help):
model = torch.nn.Sequential(
    torch.nn.Linear(D_i, D_k), # preactivation of Layer 1
    torch.nn.ReLU(), # activation of Layer 1
    torch.nn.Linear(D_k, D_k), # preactivation of Layer 1
    torch.nn.ReLU(), # activation of Layer 1
    torch.nn.Linear(D_k, D_o), # activation of Layer 2
    );


def weights_init(layer_in):
  # TODO:
  # Initialize the parameters with He initialization
  # Replace this line (see figure 7.8 of book for help)
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_normal_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)
  print("Initializing layer")


# Call the function you just defined
model.apply(weights_init)
# Out:
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Sequential(
#   (0): Linear(in_features=40, out_features=100, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=100, out_features=100, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=100, out_features=10, bias=True)
# )

# %%
# choose cross entropy loss function (equation 5.24)
loss_function = torch.nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 10 epochs
scheduler = StepLR(optimizer, step_size=10, gamma=0.5)
x_train = torch.tensor(data['x'].astype('float32'))
y_train = torch.tensor(data['y'].transpose().astype('int64'))
x_test= torch.tensor(data['x_test'].astype('float32'))
y_test = torch.tensor(data['y_test'].astype('int64'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 50
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_test = np.zeros((n_epoch))
errors_test = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, batch in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = batch
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_test = model(x_test)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_test_class = torch.max(pred_test.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_test[epoch]= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_test[epoch]= loss_function(pred_test, y_test).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  test loss {losses_test[epoch]:.6f}, test error {errors_test[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Epoch     0, train loss 1.570125, train error 61.58,  test loss 1.687886, test error 66.90
# Epoch     1, train loss 1.297586, train error 48.95,  test loss 1.463242, test error 57.80
# Epoch     2, train loss 1.143944, train error 42.28,  test loss 1.379088, test error 53.60
# Epoch     3, train loss 1.019449, train error 36.72,  test loss 1.274910, test error 48.80
# Epoch     4, train loss 0.888448, train error 32.15,  test loss 1.180555, test error 46.60
# Epoch     5, train loss 0.802015, train error 28.40,  test loss 1.169318, test error 45.80
# Epoch     6, train loss 0.679627, train error 22.40,  test loss 1.098880, test error 42.00
# Epoch     7, train loss 0.646196, train error 23.75,  test loss 1.159129, test error 40.30
# Epoch     8, train loss 0.593395, train error 20.28,  test loss 1.129761, test error 41.00
# Epoch     9, train loss 0.540770, train error 18.95,  test loss 1.154650, test error 41.50
# Epoch    10, train loss 0.398678, train error 10.93,  test loss 1.010408, test error 36.90
# Epoch    11, train loss 0.353844, train error 9.15,  test loss 1.021744, test error 36.80
# Epoch    12, train loss 0.329981, train error 8.68,  test loss 1.080662, test error 39.00
# Epoch    13, train loss 0.302412, train error 7.78,  test loss 1.083441, test error 37.90
# Epoch    14, train loss 0.273247, train error 6.65,  test loss 1.065389, test error 37.30
# Epoch    15, train loss 0.235944, train error 4.45,  test loss 1.070739, test error 36.40
# Epoch    16, train loss 0.226014, train error 4.78,  test loss 1.091725, test error 36.30
# Epoch    17, train loss 0.205534, train error 3.85,  test loss 1.095228, test error 37.00
# Epoch    18, train loss 0.183464, train error 3.18,  test loss 1.157537, test error 37.70
# Epoch    19, train loss 0.155858, train error 2.10,  test loss 1.166736, test error 36.90
# Epoch    20, train loss 0.142039, train error 1.78,  test loss 1.167281, test error 37.70
# Epoch    21, train loss 0.134025, train error 1.50,  test loss 1.161907, test error 37.30
# Epoch    22, train loss 0.126651, train error 1.18,  test loss 1.178030, test error 37.00
# Epoch    23, train loss 0.125533, train error 1.53,  test loss 1.202328, test error 36.70
# Epoch    24, train loss 0.115952, train error 1.10,  test loss 1.184138, test error 36.70
# Epoch    25, train loss 0.109798, train error 1.03,  test loss 1.212078, test error 36.90
# Epoch    26, train loss 0.102453, train error 0.50,  test loss 1.229859, test error 36.30
# Epoch    27, train loss 0.097061, train error 0.55,  test loss 1.224044, test error 35.70
# Epoch    28, train loss 0.092297, train error 0.47,  test loss 1.227464, test error 36.10
# Epoch    29, train loss 0.087193, train error 0.22,  test loss 1.250585, test error 36.10
# Epoch    30, train loss 0.083875, train error 0.10,  test loss 1.255075, test error 36.40
# Epoch    31, train loss 0.081744, train error 0.15,  test loss 1.250264, test error 36.20
# Epoch    32, train loss 0.081205, train error 0.12,  test loss 1.268752, test error 36.30
# Epoch    33, train loss 0.077872, train error 0.07,  test loss 1.266603, test error 36.40
# Epoch    34, train loss 0.076377, train error 0.05,  test loss 1.272275, test error 36.10
# Epoch    35, train loss 0.074632, train error 0.03,  test loss 1.279909, test error 36.00
# Epoch    36, train loss 0.072750, train error 0.03,  test loss 1.282312, test error 36.30
# Epoch    37, train loss 0.071286, train error 0.03,  test loss 1.285474, test error 36.50
# Epoch    38, train loss 0.069487, train error 0.03,  test loss 1.291111, test error 35.60
# Epoch    39, train loss 0.068190, train error 0.03,  test loss 1.303141, test error 35.90
# Epoch    40, train loss 0.066819, train error 0.03,  test loss 1.301968, test error 35.90
# Epoch    41, train loss 0.066135, train error 0.03,  test loss 1.302554, test error 35.80
# Epoch    42, train loss 0.065337, train error 0.00,  test loss 1.305631, test error 35.60
# Epoch    43, train loss 0.064733, train error 0.00,  test loss 1.310400, test error 35.90
# Epoch    44, train loss 0.064021, train error 0.00,  test loss 1.308938, test error 36.00
# Epoch    45, train loss 0.063381, train error 0.03,  test loss 1.311839, test error 35.90
# Epoch    46, train loss 0.062643, train error 0.00,  test loss 1.314956, test error 35.60
# Epoch    47, train loss 0.062008, train error 0.00,  test loss 1.318335, test error 35.70
# Epoch    48, train loss 0.061387, train error 0.00,  test loss 1.322491, test error 35.60
# Epoch    49, train loss 0.060815, train error 0.00,  test loss 1.322582, test error 36.00

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_test,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Test Error %3.2f'%(errors_train[-1],errors_test[-1]))
ax.legend()
plt.show()

# Plot the results
fig, ax = plt.subplots()
ax.plot(losses_train,'r-',label='train')
ax.plot(losses_test,'b-',label='test')
ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Loss')
ax.set_title('Train loss %3.2f, Test loss %3.2f'%(losses_train[-1],losses_test[-1]))
ax.legend()
plt.show()

# %% [markdown]
# **TODO**
#
# Play with the model -- try changing the number of layers, hidden units, learning rate, batch size, momentum or anything else you like.  See if you can improve the test results.
#
# Is it a good idea to optimize the hyperparameters in this way?  Will the final result be a good estimate of the true test performance?
